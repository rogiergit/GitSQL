-- %%
-- Active processes on database
select  
    r.session_id,  
    s.login_name,  
    c.client_net_address,  
    s.host_name,  
    s.program_name,  
    st.text, s.status  
from sys.dm_exec_requests r  
inner join sys.dm_exec_sessions s  
on r.session_id = s.session_id  
left join sys.dm_exec_connections c  
on r.session_id = c.session_id  
outer apply sys.dm_exec_sql_text(r.sql_handle) st  
where client_net_address is not null and text is not null and s.status = 'running'

-- %%
-- Table list
SELECT
    s.name AS SchemaName,
    t.name AS TableName
FROM sys.tables t
LEFT OUTER JOIN sys.schemas s ON t.schema_id = s.schema_id
WHERE 1=1
and s.name <> 'x'
ORDER BY s.name, t.name

-- %%
-- Table sizes on SQL server (database)
SELECT 
    t.name AS TableName,
    s.name AS SchemaName,
    p.rows,
    CAST(ROUND(((SUM(a.total_pages) * 8) / 1024.00 / 1024.00), 2) AS NUMERIC(36, 2)) AS TotalSpaceGB,
    CAST(ROUND(((SUM(a.used_pages) * 8) / 1024.00/ 1024.00), 2) AS NUMERIC(36, 2)) AS UsedSpaceGB,
    CAST(ROUND(((SUM(a.total_pages) - SUM(a.used_pages)) * 8) / 1024.00 / 1024.00, 2) AS NUMERIC(36, 2)) AS UnusedSpaceGB    
FROM 
    sys.tables t
INNER JOIN      
    sys.indexes i ON t.object_id = i.object_id
INNER JOIN 
    sys.partitions p ON i.object_id = p.object_id AND i.index_id = p.index_id
INNER JOIN 
    sys.allocation_units a ON p.partition_id = a.container_id
LEFT OUTER JOIN 
    sys.schemas s ON t.schema_id = s.schema_id
WHERE 
    t.name NOT LIKE 'dt%' 
    AND t.is_ms_shipped = 0
    AND i.object_id > 255 
GROUP BY 
    t.name, s.name, p.rows
ORDER BY 
    TotalSpaceMB DESC, t.name

-- %%
-- Table field datatypes
SELECT
    s.name AS SchemaName,
    t.name AS TableName,
    c.name AS ColumnName,
    TYPE_NAME(c.user_type_id) AS DataType,
    c.max_length,
    c.precision,
    c.scale,
    c.is_nullable
FROM sys.tables t
INNER JOIN sys.columns c ON t.object_id = c.object_id
LEFT OUTER JOIN sys.schemas s ON t.schema_id = s.schema_id
WHERE 1=1
and s.name <> 'x'
and t.name not like '%_R'  and t.name not like '%_I'  and t.name not like '%_L'  and t.name not like '%_M'
and c.name not in ('DW_Batch','DW_SourceCode','DW_TimeStamp','DW_Id','DW_Account')
ORDER BY TableName, c.column_id;
-- Out:
-- (6114 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.312
-- <table>
-- <tr><th>SchemaName</th><th>TableName</th><th>ColumnName</th><th>DataType</th></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>CertificateId</td><td>int</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>IsSelfDeclaration</td><td>bit</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>UniqueCertificate</td><td>nvarchar</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>ValidFrom</td><td>datetime</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>ValidTo</td><td>datetime</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>VendorName</td><td>nvarchar</td></tr>
-- <tr><td>mendix</td><td>acc_VendorCertificates</td><td>VendorNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>CustomerNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>ModifiedAt</td><td>datetime</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>SystemId</td><td>uniqueidentifier</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>PHK_AdressShipTo</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>PSK_AddressShipTo</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>FHK_Customer</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>FSK_Customer</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>AdressShipToCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>Address</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>Address 2</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>City</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>Country</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>CustomerName</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>Name</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>PostCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AdressShipTo</td><td>HeaderKeysTemp_LookupKey</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>AssemblyHeaderNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>AssemblyLineNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>ModifiedAt</td><td>datetime</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>SystemId</td><td>uniqueidentifier</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>PHK_AssemblyLine</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>PSK_AssemblyLine</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FHK_AssemblyHeader</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FK_PostingDate</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_AssemblyHeader</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Bin</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_BusinessUnit</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_ItemLedgerEntryDocumentLine</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Location</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Product</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_ProductType</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Project</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Quality</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>FSK_Region</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>AssemblyNumberLineNumber</td><td>varchar</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>CreatedAt</td><td>datetime</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>Description</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>Quantity</td><td>decimal</td></tr>
-- <tr><td>dsa</td><td>AssemblyLine</td><td>UnitCost</td><td>decimal</td></tr>
-- <tr><td>dsa</td><td>BackupContractSustainabilityCodeHistory20230703</td><td>SustainabilityCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>BackupContractSustainabilityCodeHistory20230703</td><td>ContractNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>BackupContractSustainabilityCodeHistory20230703</td><td>ContractLineNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa_etl</td><td>BackupContractSustainabilityCodeHistory20230703_CustomData</td><td>SustainabilityCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa_etl</td><td>BackupContractSustainabilityCodeHistory20230703_CustomData</td><td>ContractNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa_etl</td><td>BackupContractSustainabilityCodeHistory20230703_CustomData</td><td>ContractLineNumber</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>LocationCode</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>System ID</td><td>uniqueidentifier</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Bin Ranking</td><td>int</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>BinCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>ModifiedAt</td><td>datetime</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Bin Type Code</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Block Movement</td><td>int</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>SystemId</td><td>uniqueidentifier</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>PHK_Bin</td><td>varbinary</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Code</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Created At</td><td>datetime</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>PSK_Bin</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>Bin</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Created By</td><td>uniqueidentifier</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Cross-Dock Bin</td><td>bit</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>ZoneCode</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Dedicated</td><td>bit</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Description</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Empty</td><td>bit</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Location Code</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>Bin</td><td>LineKeysTemp_LookupKey</td><td>varbinary</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Maximum Cubage</td><td>decimal</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Maximum Weight</td><td>decimal</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Modified At</td><td>datetime</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Modified By</td><td>uniqueidentifier</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Special Equipment Code</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Warehouse Class Code</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>Bin</td><td>Zone Code</td><td>nvarchar</td></tr>
-- <tr><td>bc_etl</td><td>Bin_PK</td><td>System ID</td><td>uniqueidentifier</td></tr>
-- <tr><td>bc_etl</td><td>Bin_PK</td><td>Location Code</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>BusinessUnitCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>ModifiedAt</td><td>datetime</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>SystemId</td><td>uniqueidentifier</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>PHK_BusinessUnit</td><td>varbinary</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>PSK_BusinessUnit</td><td>bigint</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>Blocked</td><td>bit</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>DimensionCode</td><td>nvarchar</td></tr>
-- <tr><td>dsa</td><td>BusinessUnit</td><td>BusinessUnitName</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>ChartOfAccounts_Chart of Account Groups$</td><td>Start</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>ChartOfAccounts_Chart of Account Groups$</td><td>End</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>ChartOfAccounts_Chart of Account Groups$</td><td>Category</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>ChartOfAccounts_Chart of Account Groups$</td><td>Type</td><td>nvarchar</td></tr>
-- <tr><td>bc</td><td>ChartOfAccounts_Chart of Account Groups$</td><td>F5</td><td>nvarchar</td></tr>
-- <tr><td>bc</td
